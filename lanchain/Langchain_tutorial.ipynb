# %%
from langchain.prompts.prompt import PromptTemplate
from langchain_openai import ChatOpenAI
from langchain.chains import LLMChain
import os
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
os.getenv("OPENAI_API_KEY")
# Out:
# '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'

# %%
information = """
From below information about the person, please prepare the short summary of the person:

Sharadchandra Govindrao Pawar (Marathi pronunciation: [ʃəɾəd̪ pəʋaːɾ], born 12 December 1940)[1] is an Indian politician. He has served as the Chief Minister of Maharashtra for four terms and has also served in the Union Council Of Ministers as the Minister of Defence in the Cabinet of P.V. Narsimha Rao and Minister of Agriculture in the Cabinet of Manmohan Singh. He is the first and former president of the Nationalist Congress Party (NCP), which he founded in 1999, after separating from the Indian National Congress. His NCP was split by his nephew, Ajit Pawar. He leads his faction of the NCP delegation in the Rajya Sabha, the upper chamber of the Indian parliament. He is the chairperson of Maha Vikas Aghadi, a regional Maharashtra-based political alliance.

Pawar comes from Baramati of Maharashtra. He is the patriarch of the influential political family—the Pawar Family—and a prominent face in Maharashtra politics. Other politicians from the family include his daughter Supriya Sule, Ajit Pawar his nephew, Rohit Rajendra Pawar a nephew's son and other members of his extended family.[2][3][4][5][6]
"""

simple_template = """
take this information {input_information} about the person, prepare answers to the following question:

Q1. what is the name of the person?
Q2. Short summary about the perosn?
"""

simple_prompt = PromptTemplate(input_variables=["input_information"] , template = simple_template)

llm = ChatOpenAI(temperature=0, model="gpt-3.5-turbo", api_key=os.getenv("OPENAI_API_KEY"))

chain = simple_prompt | llm

chain.invoke(input = {"input_information":information})
# Out:
# ---------------------------------------------------------------------------
# AuthenticationError                       Traceback (most recent call last)
# Cell In[15], line 22
#      18 llm = ChatOpenAI(temperature=0, model="gpt-3.5-turbo", api_key=os.getenv("OPENAI_API_KEY"))
#      20 chain = simple_prompt | llm
# ---> 22 chain.invoke(input = {"input_information":information})
#
# File d:\ChatBot\myenv\lib\site-packages\langchain_core\runnables\base.py:2878, in RunnableSequence.invoke(self, input, config, **kwargs)
#    2876             input = context.run(step.invoke, input, config, **kwargs)
#    2877         else:
# -> 2878             input = context.run(step.invoke, input, config)
#    2879 # finish the root run
#    2880 except BaseException as e:
#
# File d:\ChatBot\myenv\lib\site-packages\langchain_core\language_models\chat_models.py:276, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     265 def invoke(
#     266     self,
# ...

# %%
simple_prompt
# Out:
# PromptTemplate(input_variables=[], template="\nFrom below information about the person, please prepare the short summary of the person:\n\nSharadchandra Govindrao Pawar (Marathi pronunciation: [ʃəɾəd̪ pəʋaːɾ], born 12 December 1940)[1] is an Indian politician. He has served as the Chief Minister of Maharashtra for four terms and has also served in the Union Council Of Ministers as the Minister of Defence in the Cabinet of P.V. Narsimha Rao and Minister of Agriculture in the Cabinet of Manmohan Singh. He is the first and former president of the Nationalist Congress Party (NCP), which he founded in 1999, after separating from the Indian National Congress. His NCP was split by his nephew, Ajit Pawar. He leads his faction of the NCP delegation in the Rajya Sabha, the upper chamber of the Indian parliament. He is the chairperson of Maha Vikas Aghadi, a regional Maharashtra-based political alliance.\n\nPawar comes from Baramati of Maharashtra. He is the patriarch of the influential politic
# ...
